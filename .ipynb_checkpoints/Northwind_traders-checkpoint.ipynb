# %%
# %load_ext sql

# %%
import os
password = os.getenv('DB_PASSWORD')
connection_string = f'postgresql://postgres:{password}@localhost:5432/northwind'

# %%
# %sql $connection_string

# %% [markdown]
# # SQL NORTHWIND TRADERS PROJECT
#
# First, we'll start by analyzing the contents of the `northwind` database
#
# ![image.png](attachment:image.png)

# %%
# %%sql
# SELECT table_name AS name,
#        table_type AS type
#   FROM information_schema.tables
#  WHERE table_schema = 'public' AND table_type IN ('BASE TABLE', 'VIEW');
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 17 rows affected.
# [('orders', 'BASE TABLE'),
#  ('employees', 'BASE TABLE'),
#  ('shippers', 'BASE TABLE'),
#  ('products', 'BASE TABLE'),
#  ('region', 'BASE TABLE'),
#  ('territories', 'BASE TABLE'),
#  ('customer_customer_demo', 'BASE TABLE'),
#  ('customer_order_view', 'VIEW'),
#  ('products_orders_details_view', 'VIEW'),
#  ('employees_orders_view', 'VIEW'),
#  ('customer_demographics', 'BASE TABLE'),
#  ('customers', 'BASE TABLE'),
#  ('categories', 'BASE TABLE'),
#  ('employee_territories', 'BASE TABLE'),
#  ('order_details', 'BASE TABLE'),
#  ('us_states', 'BASE TABLE'),
#  ('suppliers', 'BASE TABLE')]

# %% [markdown]
# Lets analyze some of the contents of the tables in the `northwind` database

# %%
# %%sql
# SELECT *
#   FROM customers
#   LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 5 rows affected.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67')]

# %%
# %%sql
# SELECT *
#   FROM orders
#  LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 5 rows affected.
# [(10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France'),
#  (10249, 'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany'),
#  (10250, 'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, 'Hanari Carnes', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil'),
#  (10251, 'VICTE', 3, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 15), 1, 41.34, 'Victuailles en stock', '2, rue du Commerce', 'Lyon', None, '69004', 'France'),
#  (10252, 'SUPRD', 4, datetime.date(1996, 7, 9), datetime.date(1996, 8, 6), datetime.date(1996, 7, 11), 2, 51.3, 'Suprêmes délices', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium')]

# %%
# %%sql
# SELECT *
#   FROM order_details
#  LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 5 rows affected.
# [(10248, 11, 14.0, 12, 0.0),
#  (10248, 42, 9.8, 10, 0.0),
#  (10248, 72, 34.8, 5, 0.0),
#  (10249, 14, 18.6, 9, 0.0),
#  (10249, 51, 42.4, 40, 0.0)]

# %%
# %%sql
# SELECT *
#   FROM products
#  LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 5 rows affected.
# [(1, 'Chai', 8, 1, '10 boxes x 30 bags', 18.0, 39, 0, 10, 1),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 1),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22.0, 53, 0, 0, 0),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35, 0, 0, 0, 1)]

# %%
# %%sql
# SELECT employee_id,
#        last_name || ' ' || first_name AS full_name,
#        reports_to
#   FROM employees
#  LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 5 rows affected.
# [(1, 'Davolio Nancy', 2),
#  (2, 'Fuller Andrew', None),
#  (3, 'Leverling Janet', 2),
#  (4, 'Peacock Margaret', 2),
#  (5, 'Buchanan Steven', 2)]

# %% [markdown]
# Now i will perform some joing to keep valuable information for analysis together. For further use, i will be saving this joined tables in `views`.
#
# I will be perfoming joins on the following tables:
# 1. Combine `orders` and `customers`.
# 2. Combine `order_details`, `products`, and `orders` tables to get detailed order infomation, including the product name and quantity.
# 3. Combine `employees` and `orders` tables to see who is responsible for each orderd.

# %%
# %%sql
# CREATE VIEW customer_order_view AS
# SELECT o.order_id, o.order_date,
#        c.company_name, c.contact_name
#   FROM orders o
#   JOIN customers c
#     ON c.customer_id = o.customer_id
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# (psycopg2.errors.DuplicateTable) relation "customer_order_view" already exists
#
# [SQL: CREATE VIEW customer_order_view AS
# SELECT o.order_id, o.order_date,
#        c.company_name, c.contact_name
#   FROM orders o
#   JOIN customers c
#     ON c.customer_id = o.customer_id]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# CREATE VIEW products_orders_details_view AS
# SELECT od.quantity, od.unit_price,
#        p.product_id, p.product_name,
#        o.order_id, o.order_date
#   FROM order_details od
#   JOIN products p
#     ON p.product_id = od.product_id
#   JOIN orders o
#     ON o.order_id = od.order_id
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# (psycopg2.errors.DuplicateTable) relation "products_orders_details_view" already exists
#
# [SQL: CREATE VIEW products_orders_details_view AS
# SELECT od.quantity, od.unit_price,
#        p.product_id, p.product_name,
#        o.order_id, o.order_date
#   FROM order_details od
#   JOIN products p
#     ON p.product_id = od.product_id
#   JOIN orders o
#     ON o.order_id = od.order_id]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# CREATE VIEW employees_orders_view AS
# SELECT e.first_name || ' ' || e.last_name AS employee_name,
#        o.order_id, o.order_date
#   FROM employees e
#   JOIN orders o
#     ON o.employee_id = e.employee_id
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# (psycopg2.errors.DuplicateTable) relation "employees_orders_view" already exists
#
# [SQL: CREATE VIEW employees_orders_view AS
# SELECT e.first_name || ' ' || e.last_name AS employee_name,
#        o.order_id, o.order_date
#   FROM employees e
#   JOIN orders o
#     ON o.employee_id = e.employee_id]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## Ranking employee sales performance

# %%
# %%sql
# WITH employee_sales AS (
# SELECT e.employee_id, e.first_name || ' ' || e.last_name AS employee_name,
#        ROUND(SUM(od.quantity * od.unit_price * (1-od.discount))::numeric,4) AS total_sales
#   FROM orders o
#   JOIN order_details od ON od.order_id = o.order_id
#   JOIN employees e ON e.employee_id = o.employee_id
#  GROUP BY e.employee_id
# )
#
# SELECT employee_id, employee_name,
#        RANK() OVER(ORDER BY total_sales DESC)
#   FROM employee_sales;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 9 rows affected.
# [(4, 'Margaret Peacock', 1),
#  (3, 'Janet Leverling', 2),
#  (1, 'Nancy Davolio', 3),
#  (2, 'Andrew Fuller', 4),
#  (8, 'Laura Callahan', 5),
#  (7, 'Robert King', 6),
#  (9, 'Anne Dodsworth', 7),
#  (6, 'Michael Suyama', 8),
#  (5, 'Steven Buchanan', 9)]

# %% [markdown]
# Now we can see the top-performing employees by viewing the rank column. The rank column indicates the relative performance of each employee based on their total sales, with a lower rank indicating higher sales performance.

# %% [markdown]
# ## Running Total of Monthly Sales

# %%
# %%sql
# WITH total_monthly_sales AS (
# SELECT
#     DATE_TRUNC('month', order_date)::DATE AS "Month",
#     SUM(quantity*unit_price * (1-discount)) AS "Total Sales"
#   FROM order_details od
#   JOIN orders o ON o.order_id = od.order_id
#  GROUP BY DATE_TRUNC('month', order_date)
# )
#
# SELECT
#     "Month",
#     SUM("Total Sales") OVER(ORDER BY "Month") AS "Running Total"
#   FROM total_monthly_sales;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 23 rows affected.
# [(datetime.date(1996, 7, 1), 27861.89512966156),
#  (datetime.date(1996, 8, 1), 53347.17020040483),
#  (datetime.date(1996, 9, 1), 79728.57033299239),
#  (datetime.date(1996, 10, 1), 117244.29527847127),
#  (datetime.date(1996, 11, 1), 162844.3404896083),
#  (datetime.date(1996, 12, 1), 208083.97098282274),
#  (datetime.date(1997, 1, 1), 269342.0411508011),
#  (datetime.date(1997, 2, 1), 307825.6761011254),
#  (datetime.date(1997, 3, 1), 346372.8962108522),
#  (datetime.date(1997, 4, 1), 399405.8485997937),
#  (datetime.date(1997, 5, 1), 453187.13842493534),
#  (datetime.date(1997, 6, 1), 489549.9407597378),
#  (datetime.date(1997, 7, 1), 540570.7982783426),
#  (datetime.date(1997, 8, 1), 587858.4679665978),
#  (datetime.date(1997, 9, 1), 643487.7103683471),
#  (datetime.date(1997, 10, 1), 710236.9361440743),
#  (datetime.date(1997, 11, 1), 753770.7449116395),
#  (datetime.date(1997, 12, 1), 825169.1733755233),
#  (datetime.date(1998, 1, 1), 919391.2835824591),
#  (datetime.date(1998, 2, 1), 1018806.5709654673),
#  (datetime.date(1998, 3, 1), 1123660.7259656242),
#  (datetime.date(1998, 4, 1), 1247459.4082211715),
#  (datetime.date(1998, 5, 1), 1265793.0386533642)]

# %% [markdown]
# ## Month-Over-Month Sales Growth

# %%
# %%sql
# WITH monthly_sales AS (
# SELECT
#     EXTRACT('month' from order_date) AS "Month",
#     EXTRACT('year' from order_date) AS "Year",
#     ROUND(SUM(quantity*unit_price * (1-discount))::numeric,4) AS "Total Sales"
#   FROM order_details od
#   JOIN orders o ON o.order_id = od.order_id
#  GROUP BY EXTRACT('year' from order_date), EXTRACT('month' from order_date)
# ),
# lagged_sales AS (
# SELECT
#     *,
#     LAG("Total Sales") OVER(ORDER BY "Year", "Month") AS "Previous Month Sales"
#   FROM monthly_sales
# )
#
# SELECT
#     "Year", "Month",
#     ROUND((("Total Sales" - "Previous Month Sales") / "Previous Month Sales"::numeric * 100)::numeric, 4) AS growth_rate_percentage
#   FROM lagged_sales
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 23 rows affected.
# [(Decimal('1996'), Decimal('7'), None),
#  (Decimal('1996'), Decimal('8'), Decimal('-8.5300')),
#  (Decimal('1996'), Decimal('9'), Decimal('3.5162')),
#  (Decimal('1996'), Decimal('10'), Decimal('42.2052')),
#  (Decimal('1996'), Decimal('11'), Decimal('21.5492')),
#  (Decimal('1996'), Decimal('12'), Decimal('-0.7904')),
#  (Decimal('1997'), Decimal('1'), Decimal('35.4080')),
#  (Decimal('1997'), Decimal('2'), Decimal('-37.1779')),
#  (Decimal('1997'), Decimal('3'), Decimal('0.1652')),
#  (Decimal('1997'), Decimal('4'), Decimal('37.5792')),
#  (Decimal('1997'), Decimal('5'), Decimal('1.4111')),
#  (Decimal('1997'), Decimal('6'), Decimal('-32.3876')),
#  (Decimal('1997'), Decimal('7'), Decimal('40.3106')),
#  (Decimal('1997'), Decimal('8'), Decimal('-7.3170')),
#  (Decimal('1997'), Decimal('9'), Decimal('17.6401')),
#  (Decimal('1997'), Decimal('10'), Decimal('19.9895')),
#  (Decimal('1997'), Decimal('11'), Decimal('-34.7801')),
#  (Decimal('1997'), Decimal('12'), Decimal('64.0069')),
#  (Decimal('1998'), Decimal('1'), Decimal('31.9666')),
#  (Decimal('1998'), Decimal('2'), Decimal('5.5116')),
#  (Decimal('1998'), Decimal('3'), Decimal('5.4709')),
#  (Decimal('1998'), Decimal('4'), Decimal('18.0675')),
#  (Decimal('1998'), Decimal('5'), Decimal('-85.1908'))]

# %% [markdown]
# ## Identifying High-Value Customers

# %%
# %%sql
# WITH customer_order_val AS (
# SELECT
#     o.customer_id,
#     o.order_id,
#     SUM(quantity * unit_price * (1-discount)) AS order_val
#   FROM orders o
#   JOIN order_details od
#     ON o.order_id = od.order_id
#  GROUP BY o.customer_id, o.order_id
# )
# SELECT
#     customer_id, order_id, order_val,
#     CASE
#         WHEN order_val > AVG(order_val) OVER() THEN 'Above Average'
#         WHEN order_val = AVG(order_val) OVER() THEN 'Average'
#         ELSE 'Below Average'
#     END AS value_category
#   FROM customer_order_val
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 830 rows affected.
# [('SUPRD', 11038, 732.5999981999397, 'Below Average'),
#  ('CACTU', 10782, 12.5, 'Below Average'),
#  ('FAMIA', 10725, 287.7999954223633, 'Below Average'),
#  ('GOURL', 10423, 1020.0, 'Below Average'),
#  ('TORTU', 10518, 4150.050006866455, 'Above Average'),
#  ('WANDK', 10356, 1106.3999938964844, 'Below Average'),
#  ('FURIB', 10963, 57.799999594688416, 'Below Average'),
#  ('WHITC', 10596, 1180.880024897754, 'Below Average'),
#  ('ROMEY', 10282, 155.40000534057617, 'Below Average'),
#  ('QUICK', 10658, 4464.599971601367, 'Above Average'),
#  ('LILAS', 10283, 1414.8000202178955, 'Below Average'),
#  ('LETSS', 10579, 317.75, 'Below Average'),
#  ('WHITC', 10693, 2071.1999798297884, 'Above Average'),
#  ('MAISD', 10896, 750.5, 'Below Average'),
#  ('HUNGC', 10660, 1701.0, 'Above Average'),
#  ('HANAR', 10253, 1444.7999839782715, 'Below Average'),
#  ('LAMAI', 10425, 360.0, 'Below Average'),
#  ('FOLKO', 10774, 868.75, 'Below Average'),
#  ('WILMK', 10615, 120.0, 'Below Average'),
#  ('ERNSH', 10514, 8623.4499168396, 'Above Average'),
#  ('VICTE', 10850, 628.9999955892563, 'Below Average'),
#  ('TORTU', 10276, 419.99999046325684, 'Below Average'),
#  ('MAISD', 10978, 1303.1949922281503, 'Below Average'),
#  ('EASTC', 10532, 796.3499908447266, 'Below Average'),
#  ('BONAP', 10340, 2436.1799669232964, 'Above Average'),
#  ('WELLI', 10256, 517.8000068664551, 'Below Average'),
#  ('RATTC', 10889, 11380.0, 'Above Average'),
#  ('RATTC', 10294, 1887.6000080108643, 'Above Average'),
#  ('GOURL', 10959, 131.749999076128, 'Below Average'),
#  ('SAVEA', 11064, 4330.3999724164605, 'Above Average'),
#  ('WILMK', 10673, 412.35000228881836, 'Below Average'),
#  ('MAGAA', 10300, 608.0000114440918, 'Below Average'),
#  ('GROSR', 10268, 1101.1999969482422, 'Below Average'),
#  ('SPECD', 10964, 2052.5, 'Above Average'),
#  ('HUNGO', 10567, 2518.999991208315, 'Above Average'),
#  ('MAISD', 10529, 946.0, 'Below Average'),
#  ('BSBEV', 10947, 220.0, 'Below Average'),
#  ('LAZYK', 10545, 210.0, 'Below Average'),
#  ('LILAS', 10997, 1885.0, 'Above Average'),
#  ('MAGAA', 10950, 110.0, 'Below Average'),
#  ('DRACD', 11036, 1692.0, 'Above Average'),
#  ('BLAUS', 10614, 464.0, 'Below Average'),
#  ('GREAL', 10589, 72.0, 'Below Average'),
#  ('BLONP', 10628, 450.0, 'Below Average'),
#  ('ERNSH', 10403, 855.0149758464099, 'Below Average'),
#  ('FOLKO', 10762, 4337.0, 'Above Average'),
#  ('SEVES', 10869, 1630.0, 'Above Average'),
#  ('MORGK', 10277, 1200.800048828125, 'Below Average'),
#  ('FRANR', 10671, 920.0999908447266, 'Below Average'),
#  ('LILAS', 10543, 1504.4999894499779, 'Below Average'),
#  ('TOMSP', 10967, 910.3999977111816, 'Below Average'),
#  ('RATTC', 10272, 1456.0, 'Below Average'),
#  ('SUPRD', 10930, 2255.500035174191, 'Above Average'),
#  ('DRACD', 10797, 420.0, 'Below Average'),
#  ('WOLZA', 10792, 399.8499994277954, 'Below Average'),
#  ('ANTON', 10677, 813.364982623458, 'Below Average'),
#  ('WHITC', 10696, 996.0, 'Below Average'),
#  ('BONAP', 10827, 843.0, 'Below Average'),
#  ('LINOD', 10811, 851.9999856948853, 'Below Average'),
#  ('VAFFE', 10591, 812.4999904632568, 'Below Average'),
#  ('ISLAT', 10315, 516.7999973297119, 'Below Average'),
#  ('FRANR', 10860, 519.0, 'Below Average'),
#  ('WARTH', 10750, 1590.5624888464808, 'Above Average'),
#  ('GOURL', 10734, 1498.3499908447266, 'Below Average'),
#  ('PICCO', 10489, 439.1999845504761, 'Below Average'),
#  ('EASTC', 10364, 949.9999809265137, 'Below Average'),
#  ('RICAR', 10447, 914.3999824523926, 'Below Average'),
#  ('GOURL', 10709, 3424.0, 'Above Average'),
#  ('GREAL', 11040, 200.0, 'Below Average'),
#  ('RICSU', 10419, 2097.6000273466107, 'Above Average'),
#  ('CHOPS', 10254, 556.62000967741, 'Below Average'),
#  ('QUEDE', 10720, 550.0, 'Below Average'),
#  ('FRANK', 10623, 1336.9499960422515, 'Below Average'),
#  ('LAMAI', 10454, 331.19999571442605, 'Below Average'),
#  ('SAVEA', 10398, 2505.6000675201412, 'Above Average'),
#  ('QUEEN', 10637, 2761.937497998588, 'Above Average'),
#  ('LILAS', 11065, 189.41999530792236, 'Below Average'),
#  ('HANAR', 10645, 1535.0, 'Above Average'),
#  ('MEREP', 10605, 4109.700018520653, 'Above Average'),
#  ('WELLI', 10585, 142.5, 'Below Average'),
#  ('SUPRD', 11035, 1754.4999980926514, 'Above Average'),
#  ('BSBEV', 10538, 139.79999923706055, 'Below Average'),
#  ('ERNSH', 10430, 4899.200002658367, 'Above Average'),
#  ('VAFFE', 10399, 1765.600004196167, 'Above Average'),
#  ('PRINI', 11007, 2633.9000091552734, 'Above Average'),
#  ('ALFKI', 10952, 471.19999665021896, 'Below Average'),
#  ('ROMEY', 10281, 86.49999809265137, 'Below Average'),
#  ('LEHMS', 10497, 1380.5999660491943, 'Below Average'),
#  ('DUMON', 10683, 63.0, 'Below Average'),
#  ('GODOS', 10888, 605.0, 'Below Average'),
#  ('SAVEA', 10847, 4931.919979796112, 'Above Average'),
#  ('RATTC', 10761, 507.0, 'Below Average'),
#  ('QUEEN', 10659, 1227.0199903401733, 'Below Average'),
#  ('COMMI', 10494, 911.9999885559082, 'Below Average'),
#  ('SPLIR', 10329, 4578.430057654232, 'Above Average'),
#  ('GOURL', 10652, 318.83499908447266, 'Below Average'),
#  ('MEREP', 10565, 639.8999989405274, 'Below Average'),
#  ('WILMK', 11005, 586.0, 'Below Average'),
#  ('TRADH', 10496, 189.9999998509884, 'Below Average'),
#  ('QUEDE', 10989, 1353.599998474121, 'Below Average'),
#  ('BSBEV', 10578, 477.0, 'Below Average'),
#  ('NORTS', 10517, 352.0, 'Below Average'),
#  ('KOENE', 10799, 1553.4999987483025, 'Above Average'),
#  ('CACTU', 11054, 305.0, 'Below Average'),
#  ('LEHMS', 10592, 516.4674974205718, 'Below Average'),
#  ('BOTTM', 10492, 851.1999848365783, 'Below Average'),
#  ('BERGS', 10572, 1501.0849882041662, 'Below Average'),
#  ('LAUGB', 10810, 187.0, 'Below Average'),
#  ('PICCO', 10747, 1912.8500003814697, 'Above Average'),
#  ('ALFKI', 10835, 845.799999922514, 'Below Average'),
#  ('SAVEA', 10700, 1638.3999938964844, 'Above Average'),
#  ('OTTIK', 10508, 240.0, 'Below Average'),
#  ('SUPRD', 10463, 713.299994468689, 'Below Average'),
#  ('PRINI', 10336, 285.1200057077408, 'Below Average'),
#  ('AROUT', 10768, 1477.0, 'Below Average'),
#  ('HILAA', 10490, 3163.199993133545, 'Above Average'),
#  ('KOENE', 10325, 1496.9999752044678, 'Below Average'),
#  ('BOTTM', 10431, 1892.250019311905, 'Above Average'),
#  ('FOLKO', 10434, 321.1199880409241, 'Below Average'),
#  ('RICAR', 10622, 559.9999993294477, 'Below Average'),
#  ('FOLIG', 10408, 1622.4000463485718, 'Above Average'),
#  ('BONAP', 10876, 917.0, 'Below Average'),
#  ('LEHMS', 10772, 3603.220016479492, 'Above Average'),
#  ('TRAIH', 10822, 237.89999771118164, 'Below Average'),
#  ('OLDWO', 10706, 1893.000015258789, 'Above Average'),
#  ('FURIB', 10491, 259.50499591052534, 'Below Average'),
#  ('GREAL', 11006, 329.685001373291, 'Below Average'),
#  ('FRANS', 11060, 266.0, 'Below Average'),
#  ('BLAUS', 11058, 858.0, 'Below Average'),
#  ('BLONP', 10360, 7390.200078964233, 'Above Average'),
#  ('WILMK', 10695, 642.0, 'Below Average'),
#  ('HUNGO', 10373, 1366.4000498414039, 'Below Average'),
#  ('ANTON', 10365, 403.1999816894531, 'Below Average'),
#  ('KOENE', 10893, 5502.110000610352, 'Above Average'),
#  ('BLONP', 10436, 1994.5199911314248, 'Above Average'),
#  ('SEVES', 10800, 1468.9349963662773, 'Below Average'),
#  ('TORTU', 10576, 838.4500160217285, 'Below Average'),
#  ('AROUT', 10953, 4441.249996516854, 'Above Average'),
#  ('BERGS', 10875, 709.5499949343503, 'Below Average'),
#  ('HILAA', 10257, 1119.899953842163, 'Below Average'),
#  ('REGGC', 10562, 488.6999923244119, 'Below Average'),
#  ('HANAR', 10922, 742.5, 'Below Average'),
#  ('BONAP', 11076, 792.7499985694885, 'Below Average'),
#  ('FURIB', 10604, 230.84999961778522, 'Below Average'),
#  ('WOLZA', 10870, 160.0, 'Below Average'),
#  ('MAGAA', 10754, 55.19999885559082, 'Below Average'),
#  ('FRANS', 10710, 93.49999904632568, 'Below Average'),
#  ('ANTON', 10682, 375.5, 'Below Average'),
#  ('REGGC', 10727, 1624.4999987259507, 'Above Average'),
#  ('CENTC', 10259, 100.79999923706055, 'Below Average'),
#  ('VAFFE', 10602, 48.75, 'Below Average'),
#  ('KOENE', 10542, 469.1099952833355, 'Below Average'),
#  ('HUNGO', 10516, 2381.0499690555034, 'Above Average'),
#  ('BOTTM', 10389, 1832.8000297546387, 'Above Average'),
#  ('HANAR', 10770, 236.25, 'Below Average'),
#  ('WARTH', 10553, 1546.3000106811523, 'Above Average'),
#  ('WELLI', 10935, 619.5, 'Below Average'),
#  ('MORGK', 10945, 245.0, 'Below Average'),
#  ('FAMIA', 10650, 1779.1999572366476, 'Above Average'),
#  ('MEREP', 10339, 3354.0000956475733, 'Above Average'),
#  ('HUNGO', 10661, 562.5999979041517, 'Below Average'),
#  ('FRANK', 10791, 1829.7570034935625, 'Above Average'),
#  ('FAMIA', 10414, 224.83000316366554, 'Below Average'),
#  ('QUEEN', 10704, 595.5, 'Below Average'),
#  ('FRANK', 10670, 2301.75, 'Above Average'),
#  ('LAMAI', 11051, 35.99999986588955, 'Below Average'),
#  ('SIMOB', 10642, 695.999997407198, 'Below Average'),
#  ('QUEEN', 10961, 1119.8999999687076, 'Below Average'),
#  ('WHITC', 10861, 3523.3999977111816, 'Above Average'),
#  ('TOMSP', 10438, 454.00000212341547, 'Below Average'),
#  ('WOLZA', 11044, 591.5999908447266, 'Below Average'),
#  ('RANCH', 10828, 932.0, 'Below Average'),
#  ('TOMSP', 10548, 240.09999465942383, 'Below Average'),
#  ('HANAR', 10925, 475.14999666810036, 'Below Average'),
#  ('HUNGO', 10646, 1446.0, 'Below Average'),
#  ('GREAL', 10616, 4806.999996647239, 'Above Average'),
#  ('HILAA', 10601, 2285.0, 'Above Average'),
#  ('WARTH', 10526, 1151.3999923467636, 'Below Average'),
#  ('LONEP', 10665, 1295.0, 'Below Average'),
#  ('OTTIK', 10260, 1504.6500339508057, 'Below Average'),
#  ('SAVEA', 10941, 4011.7499446868896, 'Above Average'),
#  ('BONAP', 10932, 1788.629996739775, 'Above Average'),
#  ('CHOPS', 10731, 1890.4999985173345, 'Above Average'),
#  ('WHITC', 11032, 8902.5, 'Above Average'),
#  ('FRANK', 10653, 1083.1500188060104, 'Below Average'),
#  ('LONEP', 10867, 98.39999771118164, 'Below Average'),
#  ('HUNGC', 10394, 442.0000171661377, 'Below Average'),
#  ('WARTH', 10583, 2237.500002145767, 'Above Average'),
#  ('OTTIK', 10407, 1193.9999771118164, 'Below Average'),
#  ('LEHMS', 11070, 1629.9750097781418, 'Above Average'),
#  ('FOLKO', 11001, 2769.0, 'Above Average'),
#  ('QUEDE', 10379, 863.2799614918232, 'Below Average'),
#  ('REGGC', 10942, 560.0, 'Below Average'),
#  ('ALFKI', 10643, 814.4999828338623, 'Below Average'),
#  ('LINOD', 10638, 2720.0499382019043, 'Above Average'),
#  ('FURIB', 10551, 1677.300050151348, 'Above Average'),
#  ('BONAP', 10511, 2549.9999821186066, 'Above Average'),
#  ('GODOS', 10911, 858.0, 'Below Average'),
#  ('WHITC', 11066, 928.7499942779541, 'Below Average'),
#  ('ERNSH', 11008, 4680.899895212055, 'Above Average'),
#  ('RANCH', 10916, 686.7000045776367, 'Below Average'),
#  ('HUNGO', 10736, 996.9999694824219, 'Below Average'),
#  ('SAVEA', 10627, 1185.7499854266644, 'Below Average'),
#  ('SAVEA', 11030, 12615.050067901611, 'Above Average'),
#  ('LEHMS', 10284, 1170.3749935626984, 'Below Average'),
#  ('LONEP', 10317, 287.99999237060547, 'Below Average'),
#  ('LAMAI', 10413, 2123.2000465393066, 'Above Average'),
#  ('LILAS', 10461, 1538.700050354004, 'Above Average'),
#  ('BSBEV', 10539, 355.5, 'Below Average'),
#  ('LILAS', 10296, 1050.599967956543, 'Below Average'),
#  ('LINOD', 10729, 1850.0, 'Above Average'),
#  ('SPLIR', 10385, 691.2000096321106, 'Below Average'),
#  ('BERGS', 10278, 1488.7999877929688, 'Below Average'),
#  ('WILMK', 10910, 452.89999771118164, 'Below Average'),
#  ('WANDK', 10348, 363.5999890804291, 'Below Average'),
#  ('ERNSH', 10990, 4288.849974483252, 'Above Average'),
#  ('SAVEA', 10657, 4371.599990844727, 'Above Average'),
#  ('BERGS', 10672, 3815.249994110316, 'Above Average'),
#  ('EASTC', 11047, 817.8750085830688, 'Below Average'),
#  ('SEVES', 10547, 1792.7999954223633, 'Above Average'),
#  ('COMMI', 11042, 405.7500114440918, 'Below Average'),
#  ('BONAP', 10331, 88.50000143051147, 'Below Average'),
#  ('SIMOB', 10417, 11188.400139808655, 'Above Average'),
#  ('ALFKI', 10702, 330.0, 'Below Average'),
#  ('PICCO', 11053, 3054.999991003424, 'Above Average'),
#  ('PICCO', 10844, 735.0, 'Below Average'),
#  ('GREAL', 10617, 1402.4999901652336, 'Below Average'),
#  ('SUPRD', 10885, 1209.0, 'Below Average'),
#  ('SPLIR', 10821, 678.0, 'Below Average'),
#  ('BSBEV', 11023, 1500.0, 'Below Average'),
#  ('CHOPS', 10519, 2314.1999993771315, 'Above Average'),
#  ('SUPRD', 10302, 2708.800064086914, 'Above Average'),
#  ('QUICK', 10285, 1743.3599956417083, 'Above Average'),
#  ('SANTG', 10639, 500.0, 'Below Average'),
#  ('GREAL', 10681, 1287.3999942600726, 'Below Average'),
#  ('CACTU', 10819, 477.0, 'Below Average'),
#  ('RICSU', 10751, 1631.4839757028817, 'Above Average'),
#  ('FRANS', 11026, 1030.0, 'Below Average'),
#  ('LETSS', 10884, 1378.069990221709, 'Below Average'),
#  ('AROUT', 11016, 491.5, 'Below Average'),
#  ('ISLAT', 10473, 230.40000915527344, 'Below Average'),
#  ('ISLAT', 10749, 1080.0, 'Below Average'),
#  ('SEVES', 10388, 1228.8000271737576, 'Below Average'),
#  ('KOENE', 10323, 164.399995803833, 'Below Average'),
#  ('RATTC', 10564, 1234.0499990321696, 'Below Average'),
#  ('FOLKO', 10977, 2233.000030517578, 'Above Average'),
#  ('LILAS', 10381, 112.0, 'Below Average'),
#  ('FOLKO', 10460, 176.0999994277954, 'Below Average'),
#  ('PICCO', 10427, 651.0000133514404, 'Below Average'),
#  ('RICAR', 10481, 1472.0000305175781, 'Below Average'),
#  ('QUEEN', 10913, 768.75, 'Below Average'),
#  ('REGGC', 10428, 192.00000762939453, 'Below Average'),
#  ('FRANK', 10675, 1422.9999923706055, 'Below Average'),
#  ('HUNGO', 10701, 2864.4999799132347, 'Above Average'),
#  ('KOENE', 10457, 1584.0, 'Above Average'),
#  ('SANTG', 11015, 622.3499908447266, 'Below Average'),
#  ('NORTS', 10752, 252.0, 'Below Average'),
#  ('LETSS', 10735, 536.3999991118908, 'Below Average'),
#  ('BSBEV', 10289, 479.40000343322754, 'Below Average'),
#  ('VAFFE', 10769, 1684.2749773900955, 'Above Average'),
#  ('THECR', 11003, 325.99999618530273, 'Below Average'),
#  ('HILAA', 10957, 1762.6999816894531, 'Above Average'),
#  ('ERNSH', 10764, 2285.999996215105, 'Above Average'),
#  ('EASTC', 10726, 655.0, 'Below Average'),
#  ('CHOPS', 11041, 1773.0000440776348, 'Above Average'),
#  ('FRANS', 10807, 18.399999618530273, 'Below Average'),
#  ('BERGS', 10689, 472.5, 'Below Average'),
#  ('RATTC', 10401, 3868.6000175476074, 'Above Average'),
#  ('VICTE', 10814, 1788.4499811828136, 'Above Average'),
#  ('HANAR', 10690, 862.5, 'Below Average'),
#  ('ANATR', 10759, 320.0, 'Below Average'),
#  ('OLDWO', 10441, 1754.9999237060547, 'Above Average'),
#  ('QUICK', 10540, 10191.699981689453, 'Above Average'),
#  ('PRINI', 10433, 851.1999893188477, 'Below Average'),
#  ('WOLZA', 10906, 427.5, 'Below Average'),
#  ('BLAUS', 10582, 330.0, 'Below Average'),
#  ('HUNGC', 10415, 102.4000015258789, 'Below Average'),
#  ('FOLKO', 10378, 103.20000457763672, 'Below Average'),
#  ('QUICK', 10938, 2731.875, 'Above Average'),
#  ('PICCO', 10686, 1404.4499896466732, 'Below Average'),
#  ('MAGAA', 10635, 1326.2250043448062, 'Below Average'),
#  ('WARTH', 10437, 393.0000114440918, 'Below Average'),
#  ('QUICK', 10845, 3812.699996329844, 'Above Average'),
#  ('AROUT', 10741, 227.9999991506338, 'Below Average'),
#  ('LILAS', 10357, 1167.6799776029588, 'Below Average'),
#  ('BONAP', 10663, 1930.3999876141547, 'Above Average'),
#  ('THECR', 10624, 1393.2399978637695, 'Below Average'),
#  ('FURIB', 10352, 136.2999999642372, 'Below Average'),
#  ('RATTC', 10262, 583.9999986290932, 'Below Average'),
#  ('VAFFE', 10465, 2517.999988231063, 'Above Average'),
#  ('HUNGO', 10912, 6200.5500411987305, 'Above Average'),
#  ('NORTS', 11057, 45.0, 'Below Average'),
#  ('FOLKO', 10824, 250.79999542236328, 'Below Average'),
#  ('SAVEA', 10714, 2205.75, 'Above Average'),
#  ('ERNSH', 10968, 1408.0, 'Below Average'),
#  ('SAVEA', 10612, 6375.0, 'Above Average'),
#  ('RICAR', 10813, 602.399999320507, 'Below Average'),
#  ('RICAR', 10648, 372.37499959766865, 'Below Average'),
#  ('RICSU', 10931, 799.199998497963, 'Below Average'),
#  ('GOURL', 11049, 273.5999989807606, 'Below Average'),
#  ('VINET', 10295, 121.5999984741211, 'Below Average'),
#  ('ERNSH', 10571, 550.5874961391091, 'Below Average'),
#  ('OLDWO', 10855, 2227.887526537478, 'Above Average'),
#  ('LILAS', 10330, 1648.9999560117722, 'Above Average'),
#  ('OLDWO', 11034, 539.400008931756, 'Below Average'),
#  ('SPECD', 10907, 108.5, 'Below Average'),
#  ('GODOS', 10303, 1117.7999706834555, 'Below Average'),
#  ('TOMSP', 10608, 1064.0, 'Below Average'),
#  ('WARTH', 11025, 269.99999955296516, 'Below Average'),
#  ('LAZYK', 10482, 146.99999809265137, 'Below Average'),
#  ('GALED', 10887, 70.0, 'Below Average'),
#  ('HILAA', 10976, 911.9999694824219, 'Below Average'),
#  ('SPLIR', 10349, 141.60000228881836, 'Below Average'),
#  ('ANATR', 10308, 88.79999923706055, 'Below Average'),
#  ('WILMK', 10879, 611.2999877929688, 'Below Average'),
#  ('WELLI', 10644, 1371.7999992519617, 'Below Average'),
#  ('ERNSH', 10368, 1689.7800372537972, 'Above Average'),
#  ('BONAP', 10755, 1948.5, 'Above Average'),
#  ('WHITC', 10740, 1415.9999886214732, 'Below Average'),
#  ('ISLAT', 10674, 45.0, 'Below Average'),
#  ('AROUT', 10864, 282.0, 'Below Average'),
#  ('LINOD', 10405, 400.0, 'Below Average'),
#  ('GODOS', 10550, 683.2999971136451, 'Below Average'),
#  ('BLAUS', 10509, 136.79999542236328, 'Below Average'),
#  ('OCEAN', 10958, 781.0000038146973, 'Below Average'),
#  ('ROMEY', 10306, 498.5000157356262, 'Below Average'),
#  ('SUPRD', 10252, 3597.9001445159315, 'Above Average'),
#  ('ERNSH', 10979, 4813.500099182129, 'Above Average'),
#  ('GODOS', 10948, 2362.25, 'Above Average'),
#  ('MAGAA', 10275, 291.8399986839294, 'Below Average'),
#  ('SAVEA', 11031, 2393.5, 'Above Average'),
#  ('BLONP', 10584, 593.7499995343387, 'Below Average'),
#  ('BERGS', 10733, 1458.9999694824219, 'Below Average'),
#  ('REGGC', 10812, 1692.7999701619149, 'Above Average'),
#  ('HUNGO', 10897, 10835.240051269531, 'Above Average'),
#  ('GOURL', 10790, 722.4999949336052, 'Below Average'),
#  ('SEVES', 10359, 3471.680034966469, 'Above Average'),
#  ('SAVEA', 10324, 5275.714843202234, 'Above Average'),
#  ('GROSR', 10785, 387.5, 'Below Average'),
#  ('HUNGC', 10600, 479.79999923706055, 'Below Average'),
#  ('TOMSP', 10446, 246.23999864816668, 'Below Average'),
#  ('PICCO', 10597, 718.079991453588, 'Below Average'),
#  ('KOENE', 10506, 415.79999931156635, 'Below Average'),
#  ('FOLKO', 10993, 4895.437524318695, 'Above Average'),
#  ('LEHMS', 10593, 1994.399992570281, 'Above Average'),
#  ('QUICK', 10527, 1502.999997511506, 'Below Average'),
#  ('SAVEA', 10757, 3081.9999771118164, 'Above Average'),
#  ('TRAIH', 10574, 764.299991607666, 'Below Average'),
#  ('KOENE', 10849, 967.8189896456004, 'Below Average'),
#  ('AROUT', 10453, 407.69999675005675, 'Below Average'),
#  ('LACOR', 10927, 800.0, 'Below Average'),
#  ('CONSH', 10435, 631.5999813079834, 'Below Average'),
#  ('QUEDE', 10421, 1194.2699925529955, 'Below Average'),
#  ('LONEP', 10307, 424.00001525878906, 'Below Average'),
#  ('BLAUS', 10501, 148.99999618530273, 'Below Average'),
#  ('DRACD', 10363, 447.1999931335449, 'Below Average'),
#  ('WHITC', 10904, 1924.2499732971191, 'Above Average'),
#  ('THEBI', 10708, 180.4000015258789, 'Below Average'),
#  ('QUEDE', 10647, 635.9999942779541, 'Below Average'),
#  ('ERNSH', 10698, 3436.443460877441, 'Above Average'),
#  ('BERGS', 10866, 1096.1999816894531, 'Below Average'),
#  ('RICAR', 10287, 818.9999839067459, 'Below Average'),
#  ('MAISD', 11004, 295.37999725341797, 'Below Average'),
#  ('LONEP', 10544, 417.19998931884766, 'Below Average'),
#  ('ERNSH', 10263, 1873.8000144958496, 'Above Average'),
#  ('SAVEA', 10452, 2018.5000217333436, 'Above Average'),
#  ('PICCO', 10392, 1439.9999618530273, 'Below Average'),
#  ('QUICK', 10878, 1538.999998793006, 'Above Average'),
#  ('ERNSH', 10442, 1792.0000076293945, 'Above Average'),
#  ('CACTU', 10937, 644.7999877929688, 'Below Average'),
#  ('BOTTM', 11045, 1309.5, 'Below Average'),
#  ('WANDK', 10651, 397.79999828338623, 'Below Average'),
#  ('PERIC', 11073, 300.0, 'Below Average'),
#  ('HANAR', 11052, 1331.9999950379133, 'Below Average'),
#  ('FRANK', 10929, 1174.75, 'Below Average'),
#  ('LILAS', 10823, 2825.999995805323, 'Above Average'),
#  ('QUICK', 10694, 4825.0, 'Above Average'),
#  ('MAGAA', 10404, 1591.2499806322157, 'Above Average'),
#  ('ERNSH', 10382, 2900.0, 'Above Average'),
#  ('EASTC', 10987, 2771.999984741211, 'Above Average'),
#  ('LONEP', 10662, 125.0, 'Below Average'),
#  ('OTTIK', 10554, 1728.5250058922916, 'Above Average'),
#  ('MEREP', 10570, 2465.2499980665743, 'Above Average'),
#  ('QUEEN', 10406, 1830.7800498691201, 'Above Average'),
#  ('RICAR', 10563, 965.0, 'Below Average'),
#  ('RATTC', 10852, 2983.9999618530273, 'Above Average'),
#  ('SAVEA', 10722, 1570.0, 'Above Average'),
#  ('TORTU', 10319, 1191.2000160217285, 'Below Average'),
#  ('DUMON', 10890, 860.0999946594238, 'Below Average'),
#  ('FRANK', 10717, 1270.7499962300062, 'Below Average'),
#  ('WOLZA', 10374, 459.0000057220459, 'Below Average'),
#  ('OLDWO', 10305, 3741.2999835059045, 'Above Average'),
#  ('ERNSH', 10258, 1614.8799881857633, 'Above Average'),
#  ('HILAA', 10395, 2122.9200484412904, 'Above Average'),
#  ('WHITC', 10723, 468.4499931335449, 'Below Average'),
#  ('OTTIK', 10766, 2310.0, 'Above Average'),
#  ('GODOS', 10872, 2058.4599686691163, 'Above Average'),
#  ('DUMON', 10311, 268.79999351501465, 'Below Average'),
#  ('TORTU', 10915, 539.4999980926514, 'Below Average'),
#  ('SAVEA', 10894, 2753.0999978408217, 'Above Average'),
#  ('BOTTM', 10944, 1025.3250102996826, 'Below Average'),
#  ('CACTU', 10881, 150.0, 'Below Average'),
#  ('REGGC', 10288, 80.10000072568656, 'Below Average'),
#  ('BOTTM', 10742, 3117.999973297119, 'Above Average'),
#  ('QUICK', 10451, 3849.660049931109, 'Above Average'),
#  ('VINET', 10274, 538.6000099182129, 'Below Average'),
#  ('ANATR', 10625, 479.75, 'Below Average'),
#  ('SAVEA', 10713, 2827.89998626709, 'Above Average'),
#  ('SAVEA', 10440, 4924.134883921743, 'Above Average'),
#  ('FRANK', 10859, 1078.6874949932098, 'Below Average'),
#  ('ANTON', 10535, 1940.8499933533371, 'Above Average'),
#  ('GREAL', 10816, 8446.449978879838, 'Above Average'),
#  ('SAVEA', 10555, 2944.399983690679, 'Above Average'),
#  ('TRADH', 10834, 1432.7139942376912, 'Below Average'),
#  ('CONSH', 10848, 931.5000114440918, 'Below Average'),
#  ('BSBEV', 10471, 1327.9999923706055, 'Below Average'),
#  ('AROUT', 10920, 390.0, 'Below Average'),
#  ('SIMOB', 10341, 352.59999763965607, 'Below Average'),
#  ('WARTH', 10455, 2684.0000343322754, 'Above Average'),
#  ('PERIC', 10322, 111.99999809265137, 'Below Average'),
#  ('REGGC', 10586, 23.799999833106995, 'Below Average'),
#  ('BOTTM', 10949, 4421.999954223633, 'Above Average'),
#  ('HANAR', 10783, 1442.5, 'Below Average'),
#  ('MORGK', 10779, 1335.0, 'Below Average'),
#  ('RATTC', 11000, 903.75, 'Below Average'),
#  ('WILMK', 10873, 336.7999954223633, 'Below Average'),
#  ('AROUT', 10743, 319.1999997496605, 'Below Average'),
#  ('BERGS', 10654, 601.829997973591, 'Below Average'),
#  ('HANAR', 10886, 3127.5, 'Above Average'),
#  ('LAUGB', 10620, 57.5, 'Below Average'),
#  ('AROUT', 10558, 2142.89998626709, 'Above Average'),
#  ('TORTU', 11069, 360.0, 'Below Average'),
#  ('KOENE', 10718, 3463.0, 'Above Average'),
#  ('QUICK', 10996, 560.0, 'Below Average'),
#  ('BLONP', 10566, 1760.999988913536, 'Above Average'),
#  ('VICTE', 10251, 654.0599855789542, 'Below Average'),
#  ('WHITC', 10483, 668.7999822616578, 'Below Average'),
#  ('QUICK', 10418, 1814.7999711036682, 'Above Average'),
#  ('BERGS', 10626, 1503.5999908447266, 'Below Average'),
#  ('ERNSH', 10895, 6379.399965286255, 'Above Average'),
#  ('ERNSH', 10795, 2158.0000495910645, 'Above Average'),
#  ('SEVES', 10472, 1036.8000200033189, 'Below Average'),
#  ('MAGAA', 10939, 637.4999955296516, 'Below Average'),
#  ('LEHMS', 10343, 1584.000013321638, 'Above Average'),
#  ('LACOR', 10972, 251.5, 'Below Average'),
#  ('SEVES', 10804, 2278.399962902069, 'Above Average'),
#  ('QUICK', 10788, 731.4999903663993, 'Below Average'),
#  ('KOENE', 10456, 557.5999960899353, 'Below Average'),
#  ('GODOS', 10874, 310.0, 'Below Average'),
#  ('SAVEA', 10984, 1809.75004196167, 'Above Average'),
#  ('CHOPS', 10966, 1098.459985973835, 'Below Average'),
#  ('CHOPS', 11029, 1286.8000183105469, 'Below Average'),
#  ('VAFFE', 10921, 1936.0000610351562, 'Above Average'),
#  ('QUICK', 10273, 2037.2799582076073, 'Above Average'),
#  ('SIMOB', 11074, 232.08500996507703, 'Below Average'),
#  ('FAMIA', 10512, 525.299996316433, 'Below Average'),
#  ('BONAP', 10362, 1549.6000232696533, 'Above Average'),
#  ('QUICK', 10991, 2295.9999914467335, 'Above Average'),
#  ('BONAP', 10715, 1296.0, 'Below Average'),
#  ('GALED', 10928, 137.5, 'Below Average'),
#  ('WARTH', 10266, 346.55999537944797, 'Below Average'),
#  ('MEREP', 10618, 2697.5, 'Above Average'),
#  ('PRINI', 10397, 716.7200183200835, 'Below Average'),
#  ('TRADH', 10839, 827.5499883301557, 'Below Average'),
#  ('TORTU', 10293, 848.699990272522, 'Below Average'),
#  ('BERGS', 10280, 613.200008392334, 'Below Average'),
#  ('QUEEN', 10786, 1531.0799869720638, 'Above Average'),
#  ('SAVEA', 10748, 2195.999984741211, 'Above Average'),
#  ('EASTC', 10400, 3062.9999866485596, 'Above Average'),
#  ('LACOR', 10973, 291.5499954223633, 'Below Average'),
#  ('CHOPS', 10746, 2311.699993133545, 'Above Average'),
#  ('FAMIA', 10581, 309.99999884516, 'Below Average'),
#  ('QUICK', 10691, 10164.800018310547, 'Above Average'),
#  ('MEREP', 10332, 1786.8799905967712, 'Above Average'),
#  ('VAFFE', 10688, 3160.599912694097, 'Above Average'),
#  ('VICTE', 10478, 471.1999851346016, 'Below Average'),
#  ('ALFKI', 11011, 933.4999996051192, 'Below Average'),
#  ('WARTH', 10412, 334.80000631213187, 'Below Average'),
#  ('SAVEA', 10678, 5256.499948501587, 'Above Average'),
#  ('QUICK', 10962, 3583.999984741211, 'Above Average'),
#  ('GODOS', 11037, 60.0, 'Below Average'),
#  ('QUICK', 10345, 2924.8000135421753, 'Above Average'),
#  ('GOURL', 10777, 223.99999916553497, 'Below Average'),
#  ('RICAR', 10851, 2602.999997958541, 'Above Average'),
#  ('LAMAI', 10610, 299.25, 'Below Average'),
#  ('THEBI', 10992, 69.5999984741211, 'Below Average'),
#  ('MAGAA', 10467, 235.19999504089355, 'Below Average'),
#  ('ERNSH', 11072, 5217.999984741211, 'Above Average'),
#  ('ERNSH', 10633, 5510.5923958596595, 'Above Average'),
#  ('SPLIR', 10756, 1989.9999925866723, 'Above Average'),
#  ('VINET', 10737, 139.79999542236328, 'Below Average'),
#  ('LAUGB', 10495, 277.99999237060547, 'Below Average'),
#  ('KOENE', 10468, 717.5999946594238, 'Below Average'),
#  ('COMMI', 10466, 215.9999942779541, 'Below Average'),
#  ('RATTC', 10316, 2835.000104904175, 'Above Average'),
#  ('WELLI', 10905, 341.9999997317791, 'Below Average'),
#  ('HANAR', 10250, 1552.600023412704, 'Above Average'),
#  ('ERNSH', 11017, 6750.0, 'Above Average'),
#  ('FOLKO', 10902, 863.429990054369, 'Below Average'),
#  ('ERNSH', 10836, 4705.5, 'Above Average'),
#  ('RATTC', 10314, 2094.3000548973678, 'Above Average'),
#  ('MAISD', 10649, 1433.99995803833, 'Below Average'),
#  ('FAMIA', 10347, 814.4199756312371, 'Below Average'),
#  ('FOLKO', 10327, 1809.9999894425273, 'Above Average'),
#  ('GODOS', 10629, 2775.050018310547, 'Above Average'),
#  ('BSBEV', 10599, 492.99999237060547, 'Below Average'),
#  ('HILAA', 10476, 180.48000142097473, 'Below Average'),
#  ('MAGAA', 10784, 1487.9999741077424, 'Below Average'),
#  ('HUNGO', 10712, 1233.479997752309, 'Below Average'),
#  ('BOTTM', 10410, 802.0, 'Below Average'),
#  ('TORTU', 10304, 954.4000015258789, 'Below Average'),
#  ('LINOD', 11039, 3089.999969482422, 'Above Average'),
#  ('PRINI', 10477, 557.9999885559082, 'Below Average'),
#  ('BOTTM', 10975, 717.5, 'Below Average'),
#  ('OCEAN', 10898, 30.0, 'Below Average'),
#  ('LILAS', 10899, 122.39999914169312, 'Below Average'),
#  ('FOLKO', 10533, 2222.1999806016684, 'Above Average'),
#  ('VICTE', 10546, 2811.999969482422, 'Above Average'),
#  ('FRANK', 10342, 1840.640007791519, 'Above Average'),
#  ('SEVES', 10523, 2444.3099938930573, 'Above Average'),
#  ('HILAA', 10705, 378.0, 'Below Average'),
#  ('RANCH', 11019, 76.0, 'Below Average'),
#  ('HANAR', 10541, 1946.5199720579385, 'Above Average'),
#  ('BERGS', 10778, 96.49999618530273, 'Below Average'),
#  ('GALED', 10426, 338.20000076293945, 'Below Average'),
#  ('LINOD', 10954, 1659.5350085192918, 'Above Average'),
#  ('REGGC', 11010, 645.0, 'Below Average'),
#  ('SPECD', 10738, 52.35000228881836, 'Below Average'),
#  ('MAGAA', 10818, 832.9999923706055, 'Below Average'),
#  ('WARTH', 10416, 720.0000190734863, 'Below Average'),
#  ('VAFFE', 10744, 735.9999819993973, 'Below Average'),
#  ('QUEEN', 11068, 2027.0799754095078, 'Above Average'),
#  ('WELLI', 10420, 1707.839970049858, 'Above Average'),
#  ('RICSU', 10537, 1823.7999839782715, 'Above Average'),
#  ('BERGS', 10857, 2048.2124948501587, 'Above Average'),
#  ('REGGC', 10443, 517.4400143480301, 'Below Average'),
#  ('PICCO', 10353, 8593.28008273363, 'Above Average'),
#  ('RATTC', 10988, 3574.7999695956705, 'Above Average'),
#  ('MEREP', 10439, 1077.9999904632568, 'Below Average'),
#  ('HUNGO', 11063, 1342.949974439293, 'Below Average'),
#  ('FURIB', 10464, 1609.2800051403046, 'Above Average'),
#  ('HUNGO', 10309, 1761.999994277954, 'Above Average'),
#  ('RICSU', 11075, 498.0999965071678, 'Below Average'),
#  ('RATTC', 10569, 889.9999986961484, 'Below Average'),
#  ('MEREP', 10505, 147.89999771118164, 'Below Average'),
#  ('ANTON', 10573, 2081.9999809265137, 'Above Average'),
#  ('HUNGO', 10298, 2645.000009536743, 'Above Average'),
#  ('HUNGO', 10687, 4960.900009155273, 'Above Average'),
#  ('OLDWO', 10965, 848.0, 'Below Average'),
#  ('HILAA', 10863, 441.14999690651894, 'Below Average'),
#  ('QUICK', 10313, 182.39999771118164, 'Below Average'),
#  ('WARTH', 10636, 629.5, 'Below Average'),
#  ('BOLID', 10326, 982.0000057220459, 'Below Average'),
#  ('COMMI', 10290, 2168.9999961853027, 'Above Average'),
#  ('BSBEV', 10943, 711.0, 'Below Average'),
#  ('WELLI', 10900, 33.75, 'Below Average'),
#  ('BOLID', 10801, 3026.85001373291, 'Above Average'),
#  ('LINOD', 11014, 243.17998998433353, 'Below Average'),
#  ('FOLKO', 10703, 2545.0, 'Above Average'),
#  ('THECR', 10775, 228.0, 'Below Average'),
#  ('HILAA', 10641, 2053.9999771118164, 'Above Average'),
#  ('QUEEN', 10868, 1920.599989593029, 'Above Average'),
#  ('ERNSH', 10402, 2713.4998893737793, 'Above Average'),
#  ('DRACD', 11067, 86.84999656677246, 'Below Average'),
#  ('HILAA', 10796, 2341.3639919412735, 'Above Average'),
#  ('QUEDE', 10794, 314.7599979119003, 'Below Average'),
#  ('FOLKO', 10264, 695.6249881237745, 'Below Average'),
#  ('SUPRD', 10475, 1505.1799952816964, 'Below Average'),
#  ('BONAP', 10730, 484.262503244169, 'Below Average'),
#  ('FOLIG', 10789, 3687.000045776367, 'Above Average'),
#  ('ERNSH', 10773, 2030.3999972306192, 'Above Average'),
#  ('PERIC', 10502, 816.2999954223633, 'Below Average'),
#  ('WANDK', 10640, 708.75, 'Below Average'),
#  ('ERNSH', 10390, 2090.879984207153, 'Above Average'),
#  ('LINOD', 10838, 1938.375, 'Above Average'),
#  ('WANDK', 11046, 1485.7999988347292, 'Below Average'),
#  ('VINET', 10248, 439.99999809265137, 'Below Average'),
#  ('OTTIK', 11020, 632.3999955654144, 'Below Average'),
#  ('VICTE', 10843, 159.0, 'Below Average'),
#  ('DUMON', 10609, 424.0, 'Below Average'),
#  ('MEREP', 10424, 9194.560067065953, 'Above Average'),
#  ('ISLAT', 10318, 240.39999389648438, 'Below Average'),
#  ('VICTE', 10334, 144.79999923706055, 'Below Average'),
#  ('BLONP', 10679, 660.0, 'Below Average'),
#  ('BLONP', 10297, 1419.9999618530273, 'Below Average'),
#  ('WHITC', 10269, 642.1999850004911, 'Below Average'),
#  ('SAVEA', 10393, 2556.949987411499, 'Above Average'),
#  ('BERGS', 10445, 174.89999914169312, 'Below Average'),
#  ('GREAL', 10528, 392.1999930739403, 'Below Average'),
#  ('HUNGO', 10380, 1313.8200286331771, 'Below Average'),
#  ('FOLIG', 10763, 616.0, 'Below Average'),
#  ('RICAR', 11059, 1838.0, 'Above Average'),
#  ('AROUT', 10793, 191.09999465942383, 'Below Average'),
#  ('ALFKI', 10692, 878.0000305175781, 'Below Average'),
#  ('VAFFE', 10946, 1407.5, 'Below Average'),
#  ('LEHMS', 10891, 368.93249101314694, 'Below Average'),
#  ('FRANS', 10753, 88.0, 'Below Average'),
#  ('WOLZA', 10998, 686.0, 'Below Average'),
#  ('LACOR', 10858, 649.0000152587891, 'Below Average'),
#  ('LINOD', 10697, 805.424998998642, 'Below Average'),
#  ('LAMAI', 10631, 55.7999999076128, 'Below Average'),
#  ('WHITC', 10504, 1388.4999923706055, 'Below Average'),
#  ('WARTH', 10333, 877.2000301361084, 'Below Average'),
#  ('QUEEN', 10914, 537.5, 'Below Average'),
#  ('SPLIR', 10271, 48.0, 'Below Average'),
#  ('THEBI', 10310, 336.00000381469727, 'Below Average'),
#  ('FRANR', 10971, 1733.0600128173828, 'Above Average'),
#  ('CONSH', 10462, 155.99999618530273, 'Below Average'),
#  ('TOMSP', 10249, 1863.4000644683838, 'Above Average'),
#  ('KOENE', 10817, 10952.84492739618, 'Above Average'),
#  ('BERGS', 10444, 1031.699993133545, 'Below Average'),
#  ('KOENE', 11028, 2160.0, 'Above Average'),
#  ('REGGC', 10908, 663.0999994799495, 'Below Average'),
#  ('FOLIG', 10634, 4985.5, 'Above Average'),
#  ('OLDWO', 10338, 934.5000267028809, 'Below Average'),
#  ('HUNGO', 10335, 2036.160051771402, 'Above Average'),
#  ('RICAR', 10299, 349.50000286102295, 'Below Average'),
#  ('LEHMS', 10522, 2318.239977545142, 'Above Average'),
#  ('WANDK', 10301, 754.9999904632568, 'Below Average'),
#  ('RATTC', 11077, 1255.7204990328737, 'Below Average'),
#  ('OTTIK', 10833, 906.9299923186004, 'Below Average'),
#  ('FOLKO', 10955, 74.3999997228384, 'Below Average'),
#  ('VINET', 10739, 240.0, 'Below Average'),
#  ('LAMAI', 10923, 748.7999972105026, 'Below Average'),
#  ('OTTIK', 10580, 1013.744974199608, 'Below Average'),
#  ('PERIC', 10354, 568.7999954223633, 'Below Average'),
#  ('ANTON', 10856, 660.0, 'Below Average'),
#  ('ERNSH', 10771, 344.0, 'Below Average'),
#  ('LAMAI', 10358, 429.3999933212995, 'Below Average'),
#  ('LONEP', 11018, 1575.0, 'Above Average'),
#  ('FOLKO', 10561, 2844.5000076293945, 'Above Average'),
#  ('QUICK', 10286, 3016.0000228881836, 'Above Average'),
#  ('HUNGO', 10429, 1441.3749599456787, 'Below Average'),
#  ('BLAUS', 10853, 625.0, 'Below Average'),
#  ('ISLAT', 10829, 1764.0, 'Above Average'),
#  ('ERNSH', 10351, 5398.725044100359, 'Above Average'),
#  ('ROMEY', 10917, 365.88999938964844, 'Below Average'),
#  ('BLAUS', 10956, 677.0, 'Below Average'),
#  ('ERNSH', 10776, 6635.274994796142, 'Above Average'),
#  ('COMMI', 10969, 108.0, 'Below Average'),
#  ('RATTC', 10346, 1618.8800154161454, 'Above Average'),
#  ('HUNGO', 10503, 2048.499984741211, 'Above Average'),
#  ('SUPRD', 10767, 28.0, 'Below Average'),
#  ('QUEDE', 10261, 447.99999237060547, 'Below Average'),
#  ('FAMIA', 10386, 165.9999966621399, 'Below Average'),
#  ('SEVES', 10377, 863.600013399124, 'Below Average'),
#  ('OTTIK', 10999, 1197.949991812557, 'Below Average'),
#  ('BONAP', 10940, 360.0, 'Below Average'),
#  ('SAVEA', 10815, 40.0, 'Below Average'),
#  ('SAVEA', 10711, 4451.699890136719, 'Above Average'),
#  ('QUICK', 10721, 923.8750355150551, 'Below Average'),
#  ('WARTH', 10320, 516.0000228881836, 'Below Average'),
#  ('VICTE', 10459, 1659.1999763011931, 'Above Average'),
#  ('HILAA', 11055, 1727.5, 'Above Average'),
#  ('THEBI', 10805, 2775.0, 'Above Average'),
#  ('FURIB', 10664, 1288.3874812379481, 'Below Average'),
#  ('WANDK', 10513, 1941.9999927654862, 'Above Average'),
#  ('RICAR', 10877, 1955.1250171661377, 'Above Average'),
#  ('GREAL', 10936, 455.9999983012676, 'Below Average'),
#  ('BOTTM', 10918, 1447.5, 'Below Average'),
#  ('BERGS', 10837, 1064.4999904632568, 'Below Average'),
#  ('EASTC', 11056, 3740.0, 'Above Average'),
#  ('TORTU', 10676, 534.8500146865845, 'Below Average'),
#  ('GALED', 10568, 155.0, 'Below Average'),
#  ('RANCH', 10716, 706.0, 'Below Average'),
#  ('ANATR', 10926, 514.3999910354614, 'Below Average'),
#  ('QUICK', 10745, 4529.800006866455, 'Above Average'),
#  ('ISLAT', 10321, 143.99999618530273, 'Below Average'),
#  ('GODOS', 11009, 616.5, 'Below Average'),
#  ('RICSU', 10666, 4666.94002532959, 'Above Average'),
#  ('QUICK', 10549, 3554.274975076318, 'Above Average'),
#  ('LAMAI', 10493, 608.3999852597714, 'Below Average'),
#  ('RICSU', 11033, 3232.7999465823173, 'Above Average'),
#  ('MEREP', 10619, 1260.0, 'Below Average'),
#  ('PICCO', 10530, 4180.0, 'Above Average'),
#  ('MORGK', 10699, 114.0, 'Below Average'),
#  ('GREAL', 11061, 510.0, 'Below Average'),
#  ('LEHMS', 10862, 581.0, 'Below Average'),
#  ('BOTTM', 10411, 966.7999925836921, 'Below Average'),
#  ('BONAP', 10525, 818.3999944388867, 'Below Average'),
#  ('HANAR', 10903, 932.0499839782715, 'Below Average'),
#  ('LINOD', 10485, 1584.0000145435333, 'Above Average'),
#  ('FRANK', 10267, 3536.599965953827, 'Above Average'),
#  ('BERGS', 10524, 3192.6499910354614, 'Above Average'),
#  ('BONAP', 10732, 360.0, 'Below Average'),
#  ('LAMAI', 10350, 642.059986577332, 'Below Average'),
#  ('WANDK', 10668, 625.2749989647418, 'Below Average'),
#  ('SANTG', 10520, 199.99999618530273, 'Below Average'),
#  ('OTTIK', 10684, 1767.9999923706055, 'Above Average'),
#  ('HILAA', 10613, 353.1999999284744, 'Below Average'),
#  ('HILAA', 10552, 880.5, 'Below Average'),
#  ('FRANK', 10488, 1511.9999992847443, 'Below Average'),
#  ('FRANK', 11012, 2825.2999887242913, 'Above Average'),
#  ('LILAS', 10780, 720.0, 'Below Average'),
#  ('SPLIR', 10369, 2390.3999948501587, 'Above Average'),
#  ('OLDWO', 10680, 1261.8750286102295, 'Below Average'),
#  ('WANDK', 10632, 588.999999538064, 'Below Average'),
#  ('PERIC', 10995, 1196.0, 'Below Average'),
#  ('WOLZA', 10611, 808.0, 'Below Average'),
#  ('OLDWO', 10594, 565.5, 'Below Average'),
#  ('VICTE', 10806, 439.5999984741211, 'Below Average'),
#  ('ISLAT', 10798, 446.59999084472656, 'Below Average'),
#  ('RICSU', 10255, 2490.4999780654907, 'Above Average'),
#  ('QUICK', 11021, 6306.239944458008, 'Above Average'),
#  ('HILAA', 10498, 574.9999980926514, 'Below Average'),
#  ('QUICK', 10515, 9921.300194740295, 'Above Average'),
#  ('BLONP', 10449, 1838.2000408172607, 'Above Average'),
#  ('OCEAN', 10531, 110.0, 'Below Average'),
#  ('LILAS', 10499, 1411.9999694824219, 'Below Average'),
#  ('SAVEA', 10882, 892.6399910068512, 'Below Average'),
#  ('PERIC', 10474, 1249.1000261306763, 'Below Average'),
#  ('QUEEN', 10372, 9210.900135040283, 'Above Average'),
#  ('TRADH', 10292, 1296.0000610351562, 'Below Average'),
#  ('TRADH', 10606, 1130.3999896854161, 'Below Average'),
#  ('FRANK', 10560, 1072.4249792099, 'Below Average'),
#  ('WHITC', 10469, 956.6749754577877, 'Below Average'),
#  ('GALED', 10366, 135.9999942779541, 'Below Average'),
#  ('SIMOB', 10669, 570.0, 'Below Average'),
#  ('ANTON', 10507, 749.0624947473407, 'Below Average'),
#  ('SPLIR', 10432, 485.0, 'Below Average'),
#  ('LAMAI', 10832, 475.1100083673, 'Below Average'),
#  ('RATTC', 10598, 2388.5000762939453, 'Above Average'),
#  ('QUICK', 10361, 2046.240015838146, 'Above Average'),
#  ('TRAIH', 10577, 569.0, 'Below Average'),
#  ('CHOPS', 10370, 1117.6000043392182, 'Below Average'),
#  ('MAISD', 10760, 2917.0000610351562, 'Above Average'),
#  ('SAVEA', 10510, 4707.540032543242, 'Above Average'),
#  ('LAMAI', 10787, 2622.760015338063, 'Above Average'),
#  ('QUICK', 10765, 1515.599942559004, 'Below Average'),
#  ('KOENE', 10630, 903.5999997854233, 'Below Average'),
#  ('FOLIG', 10480, 755.999997138977, 'Below Average'),
#  ('MEREP', 10376, 398.9999996870756, 'Below Average'),
#  ('BLONP', 10559, 520.4099952431023, 'Below Average'),
#  ('LEHMS', 10557, 1152.5, 'Below Average'),
#  ('FRANK', 10396, 1903.8000221252441, 'Above Average'),
#  ('BSBEV', 10484, 386.2000026702881, 'Below Average'),
#  ('BERGS', 10924, 1835.6999558389189, 'Above Average'),
#  ('RICSU', 10758, 1644.5999908447266, 'Above Average'),
#  ('SPLIR', 10974, 439.00001525878906, 'Below Average'),
#  ('LAMAI', 10500, 523.2599879929423, 'Below Average'),
#  ('SANTG', 10387, 1058.4000191688538, 'Below Average'),
#  ('QUICK', 10588, 3119.9999883770943, 'Above Average'),
#  ('BONAP', 10871, 1979.2300071452557, 'Above Average'),
#  ('VAFFE', 10367, 834.1999807357788, 'Below Average'),
#  ('FOLKO', 10880, 1499.9999944120646, 'Below Average'),
#  ('LEHMS', 10934, 500.0, 'Below Average'),
#  ('HUNGO', 10985, 2023.3800213691593, 'Above Average'),
#  ('QUICK', 10865, 16387.49998714775, 'Above Average'),
#  ('RATTC', 10479, 10495.60012435913, 'Above Average'),
#  ('LEHMS', 10534, 465.69998854845767, 'Below Average'),
#  ('CACTU', 10521, 225.49999618530273, 'Below Average'),
#  ('MEREP', 10590, 1100.9999994188547, 'Below Average'),
#  ('LEHMS', 10536, 1645.0, 'Above Average'),
#  ('LINOD', 10919, 1122.8000106811523, 'Below Average'),
#  ('FRANS', 10422, 49.79999923706055, 'Below Average'),
#  ('BONAP', 10470, 1820.8000001907349, 'Above Average'),
#  ('BOTTM', 11048, 525.0, 'Below Average'),
#  ('QUEEN', 10487, 889.6999912261963, 'Below Average'),
#  ('BOLID', 10970, 223.99999916553497, 'Below Average'),
#  ('HILAA', 10486, 1272.0000343322754, 'Below Average'),
#  ('ERNSH', 10667, 1536.7999942749739, 'Above Average'),
#  ('QUEEN', 10728, 1296.7499885559082, 'Below Average'),
#  ('TORTU', 10842, 975.0, 'Below Average'),
#  ('DRACD', 10825, 1030.7599792480469, 'Below Average'),
#  ('WARTH', 10781, 975.8799972106516, 'Below Average'),
#  ('RANCH', 10448, 443.3999938964844, 'Below Average'),
#  ('HUNGC', 10375, 338.0000066757202, 'Below Average'),
#  ('BOTTM', 10982, 1014.0, 'Below Average'),
#  ('ISLAT', 10933, 920.5999984741211, 'Below Average'),
#  ('LINOD', 10840, 211.1999992132187, 'Below Average'),
#  ('BERGS', 10384, 2222.4000968933105, 'Above Average'),
#  ('AROUT', 10355, 480.0000071525574, 'Below Average'),
#  ('FRANK', 10337, 2466.9999389648438, 'Above Average'),
#  ('GREAL', 10656, 604.2150182256847, 'Below Average'),
#  ('REGGC', 10655, 154.39999332129958, 'Below Average'),
#  ('ROMEY', 11013, 361.0, 'Below Average'),
#  ('RICSU', 10951, 458.75499746583404, 'Below Average'),
#  ('SANTG', 10831, 2684.3999996185303, 'Above Average'),
#  ('OCEAN', 10986, 2220.0, 'Above Average'),
#  ('FOLKO', 10980, 247.999999076128, 'Below Average'),
#  ('RATTC', 10820, 1140.0, 'Below Average'),
#  ('ERNSH', 10854, 2966.499979197979, 'Above Average'),
#  ('LONEP', 10883, 36.0, 'Below Average'),
#  ('LETSS', 10719, 844.2524929046631, 'Below Average'),
#  ('WARTH', 10270, 1375.9999752044678, 'Below Average'),
#  ('SUPRD', 10458, 3891.000051498413, 'Above Average'),
#  ('SUPRD', 10846, 1112.0, 'Below Average'),
#  ('AROUT', 10383, 898.9999961853027, 'Below Average'),
#  ('HILAA', 10901, 934.4999885559082, 'Below Average'),
#  ('SIMOB', 10802, 2942.8124856948853, 'Above Average'),
#  ('ERNSH', 10595, 4725.0, 'Above Average'),
#  ('HILAA', 10960, 265.34999084472656, 'Below Average'),
#  ('WELLI', 10803, 1193.0099947156014, 'Below Average'),
#  ('REGGC', 11062, 406.3999923825264, 'Below Average'),
#  ('HANAR', 10981, 15810.0, 'Above Average'),
#  ('BOTTM', 11027, 877.7249879837036, 'Below Average'),
#  ('SAVEA', 11002, 1811.0999963879585, 'Above Average'),
#  ('BLONP', 10265, 1176.0000228881836, 'Below Average'),
#  ('SIMOB', 10556, 835.1999816894531, 'Below Average'),
#  ('LEHMS', 10279, 351.00000858306885, 'Below Average'),
#  ('FURIB', 10328, 1167.9999694824219, 'Below Average'),
#  ('ISLAT', 10621, 758.4999990463257, 'Below Average'),
#  ('SAVEA', 10603, 1482.999999627471, 'Below Average'),
#  ('GOURL', 10685, 801.0999984741211, 'Below Average'),
#  ('WANDK', 10312, 1614.8000011444092, 'Above Average'),
#  ('QUEDE', 10587, 807.379997253418, 'Below Average'),
#  ('SANTG', 10909, 670.0000095367432, 'Below Average'),
#  ('TRADH', 10830, 1974.0, 'Above Average'),
#  ('OLDWO', 10808, 1410.999990105629, 'Below Average'),
#  ('EASTC', 11024, 1966.8099784851074, 'Above Average'),
#  ('MEREP', 10724, 638.5, 'Below Average'),
#  ('VICTE', 10450, 425.11998666703704, 'Below Average'),
#  ('MAISD', 10892, 2089.9999983608723, 'Above Average'),
#  ('HANAR', 11022, 1401.9999933242798, 'Below Average'),
#  ('VAFFE', 10994, 940.4999992623925, 'Below Average'),
#  ('SAVEA', 10607, 6475.399974822998, 'Above Average'),
#  ('OCEAN', 10409, 319.2000045776367, 'Below Average'),
#  ('WHITC', 10344, 2296.0000133514404, 'Above Average'),
#  ('LILAS', 11071, 484.4999996200204, 'Below Average'),
#  ('SPECD', 11043, 210.0, 'Below Average'),
#  ('SAVEA', 10983, 720.8999969959259, 'Below Average'),
#  ('DRACD', 10391, 86.40000343322754, 'Below Average'),
#  ('SUPRD', 10841, 4581.0, 'Above Average'),
#  ('QUEDE', 10291, 497.5200053560734, 'Below Average'),
#  ('FOLKO', 11050, 809.9999986588955, 'Below Average'),
#  ('AROUT', 10707, 1640.999997496605, 'Above Average'),
#  ('BLONP', 10826, 730.0, 'Below Average'),
#  ('LAMAI', 10371, 72.95999881267548, 'Below Average'),
#  ('MORGK', 10575, 2147.39998626709, 'Above Average'),
#  ('WELLI', 10809, 140.0, 'Below Average')]

# %%
# %%sql
# WITH customer_order_val AS (
# SELECT
#     o.customer_id,
#     o.order_id,
#     SUM(quantity * unit_price * (1-discount)) AS order_val
#   FROM orders o
#   JOIN order_details od
#     ON o.order_id = od.order_id
#  GROUP BY o.customer_id, o.order_id
# ),
# categorized_orders AS (
# SELECT
#     customer_id, order_id, order_val,
#     CASE
#         WHEN order_val > AVG(order_val) OVER() THEN 'Above Average'
#         WHEN order_val = AVG(order_val) OVER() THEN 'Average'
#         ELSE 'Below Average'
#     END AS value_category
#   FROM customer_order_val
# )
#
# SELECT
#     customer_id,
#     COUNT(*) AS above_average_orders
#   FROM categorized_orders
#  WHERE value_category = 'Above Average'
#  GROUP BY customer_id
#  ORDER BY above_average_orders DESC
#   LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 10 rows affected.
# [('SAVEA', 26),
#  ('ERNSH', 26),
#  ('QUICK', 22),
#  ('HUNGO', 11),
#  ('RATTC', 10),
#  ('BONAP', 8),
#  ('FOLKO', 8),
#  ('RICSU', 7),
#  ('HILAA', 7),
#  ('FRANK', 7)]

# %% [markdown]
# From the output above, we can see the top ten customers in terms of order value. This list provides insights into the customers with the highest number of `above_average_orders`.

# %% [markdown]
# ## Percentage of Sales for Each Category

# %%
# %%sql
# WITH category_sales AS (
# SELECT
#     c.category_id, c.category_name,
#     SUM(quantity * p.unit_price * (1 - discount)) AS total_sales
#   FROM categories c
#   JOIN products p ON p.category_id = c.category_id
#   JOIN order_details od ON od.product_id = p.product_id
#  GROUP BY c.category_id
# )
#
# SELECT
#     category_id,
#     category_name,
#     (total_sales / SUM(total_sales) OVER()::numeric * 100) AS sales_percentage
#   FROM category_sales;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 8 rows affected.
# [(8, 'Seafood', 10.195732374296757),
#  (7, 'Produce', 7.813322138303899),
#  (1, 'Beverages', 21.331025404054746),
#  (5, 'Grains/Cereals', 7.510473482122674),
#  (2, 'Condiments', 8.400470714786307),
#  (4, 'Dairy Products', 18.556754766640545),
#  (6, 'Meat/Poultry', 12.902483709246793),
#  (3, 'Confections', 13.28973741054798)]

# %% [markdown]
# ## Top Products Per Category

# %%
# %%sql
# WITH sales_per_product AS (
# SELECT
#     p.product_id,
#     p.category_id,
#     p.product_name,
#     SUM(quantity * p.unit_price * (1 - discount)) AS total_sales
#   FROM products p
#   JOIN order_details od ON od.product_id = p.product_id
#  GROUP BY p.product_id
# ), product_ranking AS (
# SELECT
#     *,
#     ROW_NUMBER() OVER(PARTITION BY category_id
#                       ORDER BY total_sales DESC)
#   FROM sales_per_product
# )
#
# SELECT category_id, product_id, product_name, total_sales
#   FROM product_ranking
#  WHERE row_number <= 3;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 24 rows affected.
# [(1, 38, 'Côte de Blaye', 153897.1748863291),
#  (1, 43, 'Ipoh Coffee', 25109.09997367859),
#  (1, 2, 'Chang', 17719.399970583618),
#  (2, 63, 'Vegie-spread', 18343.61561246872),
#  (2, 61, "Sirop d'érable", 15022.349960759282),
#  (2, 65, 'Louisiana Fiery Hot Pepper Sauce', 14893.926944906489),
#  (3, 62, 'Tarte au sucre', 50737.09416846588),
#  (3, 20, "Sir Rodney's Marmalade", 24199.559986554086),
#  (3, 26, 'Gumbär Gummibärchen', 21662.689146941742),
#  (4, 59, 'Raclette Courdavault', 76683.74989898875),
#  (4, 60, 'Camembert Pierrot', 49877.31995112449),
#  (4, 72, 'Mozzarella di Giovanni', 27086.57939014256),
#  (5, 56, 'Gnocchi di nonna Alice', 45351.09995948523),
#  (5, 64, 'Wimmers gute Semmelknödel', 23487.467487137765),
#  (5, 42, 'Singaporean Hokkien Fried Mee', 8986.599987879395),
#  (6, 29, 'Thüringer Rostbratwurst', 84783.77159642408),
#  (6, 17, 'Alice Mutton', 35105.849979020655),
#  (6, 53, 'Perth Pasties', 22623.799456167217),
#  (7, 51, 'Manjimup Dried Apples', 43846.89994909987),
#  (7, 28, 'Rössle Sauerkraut', 27936.839044377804),
#  (7, 7, "Uncle Bob's Organic Dried Pears", 22453.49998757243),
#  (8, 18, 'Carnarvon Tigers', 30728.12496125698),
#  (8, 10, 'Ikura', 21653.499964892864),
#  (8, 40, 'Boston Crab Meat', 19055.039585784674)]
